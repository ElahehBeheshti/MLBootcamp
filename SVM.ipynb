# %% [markdown]
# # Elaheh Beheshti
# Feature Combinations
#
# For a dataset with 4 features, possible feature combinations are:
#
# Single Features:
#
# {Feature 1} | {Feature 2} | {Feature 3} | {Feature 4}
#
#
# Pairs of Features:
#
# {Feature 1, Feature 2}  |  {Feature 1, Feature 3}  |  {Feature 1, Feature 4}
#
# {Feature 2, Feature 3}  |  {Feature 2, Feature 4}  |  {Feature 3, Feature 4}
#
# Triplets of Features:
#
# {Feature 1, Feature 2, Feature 3}  |  {Feature 1, Feature 2, Feature 4}
#
# {Feature 1, Feature 3, Feature 4}  |  {Feature 2, Feature 3, Feature 4}
#
# All Four Features:
#
# {Feature 1, Feature 2, Feature 3, Feature 4}
#
# In total, there are 15 different feature subsets.

# %% [markdown]
# SVM Kernels
#
# We’ll be testing 3 different SVM kernels:
#
# Linear Kernel (linear): Suitable for linearly separable data.
#
# Radial Basis Function Kernel (rbf): Captures more complex relationships using non-linear mapping.
#
# Polynomial Kernel (poly): Applies polynomial transformations to the data, useful for specific geometric relationships.

# %% [markdown]
# C Values
#
# C is the regularization parameter that controls the trade-off between maximizing the margin and minimizing classification error. Common values to try are:
#
# 0.1
#
# 1
#
# 10
#
# 100

# %% [markdown]
# Gamma Values
#
# Gamma defines the influence of a single training example. Low values mean 'far' influence, and high values mean 'close' influence. Common values to test are:
#
# 0.01
#
# 0.1
#
# 1
#
# 10

# %% [markdown]
# Total Combinations
#
# For each feature subset, we’re testing:
#
# 3 kernels (linear, rbf, poly)
#
# 4 C values (0.1, 1, 10, 100)
#
# 4 gamma values (0.01, 0.1, 1, 10)

# %% [markdown]
# Thus, for each feature subset, we’re trying:
#
# 3(kernels)×4(C values)×4(gamma values)=48combinations
#
# Since there are 15 different feature subsets, the total number of trials is:
#
# 15(feature combinations)×48(parameter combinations)=720trials

# %% [markdown]
# Finding the Best Configuration
#
# For each trial, you’re evaluating the accuracy of the model. After evaluating all 720 combinations, the one with the highest accuracy will be
#
# reported as the best configuration. This configuration includes:
#
# Selected Feature Subset (e.g., {Feature 1, Feature 2, Feature 4})
#
# Kernel (e.g., rbf)
#
# C value (e.g., 10)
#
# Gamma value (e.g., 0.1)

# %% [markdown]
# # Import Libraries

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.svm import SVC
from sklearn.metrics import accuracy_score
from sklearn.preprocessing import StandardScaler
from itertools import combinations

# %% [markdown]
# # Load and Prepare the Dataset

# %%
columns= ['Variance', 'Skewness', 'Kurtosis', 'Entropy', 'Class']
df=pd.read_csv('/Users/elahehbeheshti/Desktop/Fall2024/Machine Learning/Algorithm/SVM/data_banknote_authentication.txt', delimiter=",", names=columns)
print(df.head(6))
# Out:
#    Variance  Skewness  Kurtosis  Entropy  Class
# 0   3.62160    8.6661   -2.8073 -0.44699      0
# 1   4.54590    8.1674   -2.4586 -1.46210      0
# 2   3.86600   -2.6383    1.9242  0.10645      0
# 3   3.45660    9.5228   -4.0112 -3.59440      0
# 4   0.32924   -4.4552    4.5718 -0.98880      0
# 5   4.36840    9.6718   -3.9606 -3.16250      0

# %%
# Split features and target
X = df.drop('Class', axis=1)
y = df['Class']

# %% [markdown]
# # Standardize the Data

# %%
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# %% [markdown]
# # Defining Feature Combinations
#
# Generate various feature combinations to try with the SVM

# %%
from itertools import combinations

# Generate all feature combinations
num_features = X.shape[1]  # Number of features in the dataset
feature_combinations = []
for i in range(1, num_features + 1):
    feature_combinations.extend(list(combinations(range(num_features), i)))

# %% [markdown]
# #  Defining SVM Parameters

# %%
# SVM kernels and hyperparameters
kernels = ['linear', 'rbf', 'poly']
C_values = [0.1, 1, 10, 100]
gamma_values = [0.01, 0.1, 1, 10]

# %% [markdown]
# # Creating the Evaluation Function
#
# Create a function that evaluates the SVM model for a given set of features and parameters:

# %%
from sklearn.svm import SVC
from sklearn.metrics import accuracy_score

def evaluate_svm(X, y, feature_indices, kernel, C, gamma):
    """
    Train and evaluate an SVM model with a given set of features and parameters.
    
    Args:
    - X (numpy array): Feature matrix.
    - y (numpy array): Target vector.
    - feature_indices (tuple): Indices of features to include.
    - kernel (str): SVM kernel type.
    - C (float): Regularization parameter.
    - gamma (float): Kernel coefficient.
    
    Returns:
    - float: Accuracy score on the test data.
    """
    # Subset the features based on selected indices
    X_subset = X[:, feature_indices]
    
    # Split into training and test sets
    X_train, X_test, y_train, y_test = train_test_split(X_subset, y, test_size=0.3, random_state=42)
    
    # Train the SVM model
    model = SVC(kernel=kernel, C=C, gamma=gamma)
    model.fit(X_train, y_train)
    
    # Predict on the test set
    y_pred = model.predict(X_test)
    
    # Return the accuracy score
    return accuracy_score(y_test, y_pred)

# %% [markdown]
# # Running the SVM with Different Feature Combinations and Parameters

# %%
# Track the best configuration
best_accuracy = 0
best_config = None

# Try all combinations
for feature_indices in feature_combinations:
    for kernel in kernels:
        for C in C_values:
            for gamma in gamma_values:
                # Calculate the accuracy for the given configuration
                accuracy = evaluate_svm(X_scaled, y.values, feature_indices, kernel, C, gamma)
                
                # Store the best configuration
                if accuracy > best_accuracy:
                    best_accuracy = accuracy
                    best_config = (feature_indices, kernel, C, gamma)

                # Print the configuration and its accuracy
                print(f"Features: {feature_indices}, Kernel: {kernel}, C: {C}, Gamma: {gamma}, Accuracy: {accuracy:.4f}")
# Out:
# Features: (0,), Kernel: linear, C: 0.1, Gamma: 0.01, Accuracy: 0.8252
# Features: (0,), Kernel: linear, C: 0.1, Gamma: 0.1, Accuracy: 0.8252
# Features: (0,), Kernel: linear, C: 0.1, Gamma: 1, Accuracy: 0.8252
# Features: (0,), Kernel: linear, C: 0.1, Gamma: 10, Accuracy: 0.8252
# Features: (0,), Kernel: linear, C: 1, Gamma: 0.01, Accuracy: 0.8252
# Features: (0,), Kernel: linear, C: 1, Gamma: 0.1, Accuracy: 0.8252
# Features: (0,), Kernel: linear, C: 1, Gamma: 1, Accuracy: 0.8252
# Features: (0,), Kernel: linear, C: 1, Gamma: 10, Accuracy: 0.8252
# Features: (0,), Kernel: linear, C: 10, Gamma: 0.01, Accuracy: 0.8228
# Features: (0,), Kernel: linear, C: 10, Gamma: 0.1, Accuracy: 0.8228
# Features: (0,), Kernel: linear, C: 10, Gamma: 1, Accuracy: 0.8228
# Features: (0,), Kernel: linear, C: 10, Gamma: 10, Accuracy: 0.8228
# Features: (0,), Kernel: linear, C: 100, Gamma: 0.01, Accuracy: 0.8228
# Features: (0,), Kernel: linear, C: 100, Gamma: 0.1, Accuracy: 0.8228
# Features: (0,), Kernel: linear, C: 100, Gamma: 1, Accuracy: 0.8228
# Features: (0,), Kernel: linear, C: 100, Gamma: 10, Accuracy: 0.8228
# Features: (0,), Kernel: rbf, C: 0.1, Gamma: 0.01, Accuracy: 0.8277
# Features: (0,), Kernel: rbf, C: 0.1, Gamma: 0.1, Accuracy: 0.8252
# Features: (0,), Kernel: rbf, C: 0.1, Gamma: 1, Accuracy: 0.8252
# Features: (0,), Kernel: rbf, C: 0.1, Gamma: 10, Accuracy: 0.8228
# Features: (0,), Kernel: rbf, C: 1, Gamma: 0.01, Accuracy: 0.8252
# Features: (0,), Kernel: rbf, C: 1, Gamma: 0.1, Accuracy: 0.8252
# Features: (0,), Kernel: rbf, C: 1, Gamma: 1, Accuracy: 0.8277
# Features: (0,), Kernel: rbf, C: 1, Gamma: 10, Accuracy: 0.8252
# Features: (0,), Kernel: rbf, C: 10, Gamma: 0.01, Accuracy: 0.8252
# Features: (0,), Kernel: rbf, C: 10, Gamma: 0.1, Accuracy: 0.8277
# Features: (0,), Kernel: rbf, C: 10, Gamma: 1, Accuracy: 0.8252
# Features: (0,), Kernel: rbf, C: 10, Gamma: 10, Accuracy: 0.8228
# Features: (0,), Kernel: rbf, C: 100, Gamma: 0.01, Accuracy: 0.8252
# Features: (0,), Kernel: rbf, C: 100, Gamma: 0.1, Accuracy: 0.8374
# Features: (0,), Kernel: rbf, C: 100, Gamma: 1, Accuracy: 0.8252
# Features: (0,), Kernel: rbf, C: 100, Gamma: 10, Accuracy: 0.8228
# Features: (0,), Kernel: poly, C: 0.1, Gamma: 0.01, Accuracy: 0.5558
# Features: (0,), Kernel: poly, C: 0.1, Gamma: 0.1, Accuracy: 0.5777
# Features: (0,), Kernel: poly, C: 0.1, Gamma: 1, Accuracy: 0.7767
# Features: (0,), Kernel: poly, C: 0.1, Gamma: 10, Accuracy: 0.7791
# Features: (0,), Kernel: poly, C: 1, Gamma: 0.01, Accuracy: 0.5558
# Features: (0,), Kernel: poly, C: 1, Gamma: 0.1, Accuracy: 0.7015
# Features: (0,), Kernel: poly, C: 1, Gamma: 1, Accuracy: 0.7816
# Features: (0,), Kernel: poly, C: 1, Gamma: 10, Accuracy: 0.7791
# Features: (0,), Kernel: poly, C: 10, Gamma: 0.01, Accuracy: 0.5558
# Features: (0,), Kernel: poly, C: 10, Gamma: 0.1, Accuracy: 0.7718
# Features: (0,), Kernel: poly, C: 10, Gamma: 1, Accuracy: 0.7791
# Features: (0,), Kernel: poly, C: 10, Gamma: 10, Accuracy: 0.7791
# Features: (0,), Kernel: poly, C: 100, Gamma: 0.01, Accuracy: 0.5777
# Features: (0,), Kernel: poly, C: 100, Gamma: 0.1, Accuracy: 0.7767
# Features: (0,), Kernel: poly, C: 100, Gamma: 1, Accuracy: 0.7791
# Features: (0,), Kernel: poly, C: 100, Gamma: 10, Accuracy: 0.7791
# Features: (1,), Kernel: linear, C: 0.1, Gamma: 0.01, Accuracy: 0.6311
# Features: (1,), Kernel: linear, C: 0.1, Gamma: 0.1, Accuracy: 0.6311
# Features: (1,), Kernel: linear, C: 0.1, Gamma: 1, Accuracy: 0.6311
# Features: (1,), Kernel: linear, C: 0.1, Gamma: 10, Accuracy: 0.6311
# Features: (1,), Kernel: linear, C: 1, Gamma: 0.01, Accuracy: 0.6311
# Features: (1,), Kernel: linear, C: 1, Gamma: 0.1, Accuracy: 0.6311
# Features: (1,), Kernel: linear, C: 1, Gamma: 1, Accuracy: 0.6311
# Features: (1,), Kernel: linear, C: 1, Gamma: 10, Accuracy: 0.6311
# Features: (1,), Kernel: linear, C: 10, Gamma: 0.01, Accuracy: 0.6311
# Features: (1,), Kernel: linear, C: 10, Gamma: 0.1, Accuracy: 0.6311
# Features: (1,), Kernel: linear, C: 10, Gamma: 1, Accuracy: 0.6311
# Features: (1,), Kernel: linear, C: 10, Gamma: 10, Accuracy: 0.6311
# Features: (1,), Kernel: linear, C: 100, Gamma: 0.01, Accuracy: 0.6311
# Features: (1,), Kernel: linear, C: 100, Gamma: 0.1, Accuracy: 0.6311
# Features: (1,), Kernel: linear, C: 100, Gamma: 1, Accuracy: 0.6311
# Features: (1,), Kernel: linear, C: 100, Gamma: 10, Accuracy: 0.6311
# Features: (1,), Kernel: rbf, C: 0.1, Gamma: 0.01, Accuracy: 0.6068
# Features: (1,), Kernel: rbf, C: 0.1, Gamma: 0.1, Accuracy: 0.6214
# Features: (1,), Kernel: rbf, C: 0.1, Gamma: 1, Accuracy: 0.6917
# Features: (1,), Kernel: rbf, C: 0.1, Gamma: 10, Accuracy: 0.7451
# Features: (1,), Kernel: rbf, C: 1, Gamma: 0.01, Accuracy: 0.6311
# Features: (1,), Kernel: rbf, C: 1, Gamma: 0.1, Accuracy: 0.6408
# Features: (1,), Kernel: rbf, C: 1, Gamma: 1, Accuracy: 0.7306
# Features: (1,), Kernel: rbf, C: 1, Gamma: 10, Accuracy: 0.7354
# Features: (1,), Kernel: rbf, C: 10, Gamma: 0.01, Accuracy: 0.6214
# Features: (1,), Kernel: rbf, C: 10, Gamma: 0.1, Accuracy: 0.6942
# Features: (1,), Kernel: rbf, C: 10, Gamma: 1, Accuracy: 0.7306
# Features: (1,), Kernel: rbf, C: 10, Gamma: 10, Accuracy: 0.7549
# Features: (1,), Kernel: rbf, C: 100, Gamma: 0.01, Accuracy: 0.6359
# Features: (1,), Kernel: rbf, C: 100, Gamma: 0.1, Accuracy: 0.7015
# Features: (1,), Kernel: rbf, C: 100, Gamma: 1, Accuracy: 0.7524
# Features: (1,), Kernel: rbf, C: 100, Gamma: 10, Accuracy: 0.7451
# Features: (1,), Kernel: poly, C: 0.1, Gamma: 0.01, Accuracy: 0.5558
# Features: (1,), Kernel: poly, C: 0.1, Gamma: 0.1, Accuracy: 0.5777
# Features: (1,), Kernel: poly, C: 0.1, Gamma: 1, Accuracy: 0.6262
# Features: (1,), Kernel: poly, C: 0.1, Gamma: 10, Accuracy: 0.6262
# Features: (1,), Kernel: poly, C: 1, Gamma: 0.01, Accuracy: 0.5558
# Features: (1,), Kernel: poly, C: 1, Gamma: 0.1, Accuracy: 0.6432
# Features: (1,), Kernel: poly, C: 1, Gamma: 1, Accuracy: 0.6262
# Features: (1,), Kernel: poly, C: 1, Gamma: 10, Accuracy: 0.6262
# Features: (1,), Kernel: poly, C: 10, Gamma: 0.01, Accuracy: 0.5558
# Features: (1,), Kernel: poly, C: 10, Gamma: 0.1, Accuracy: 0.6262
# Features: (1,), Kernel: poly, C: 10, Gamma: 1, Accuracy: 0.6262
# Features: (1,), Kernel: poly, C: 10, Gamma: 10, Accuracy: 0.6262
# Features: (1,), Kernel: poly, C: 100, Gamma: 0.01, Accuracy: 0.5777
# Features: (1,), Kernel: poly, C: 100, Gamma: 0.1, Accuracy: 0.6262
# Features: (1,), Kernel: poly, C: 100, Gamma: 1, Accuracy: 0.6262
# Features: (1,), Kernel: poly, C: 100, Gamma: 10, Accuracy: 0.6238
# Features: (2,), Kernel: linear, C: 0.1, Gamma: 0.01, Accuracy: 0.5971
# Features: (2,), Kernel: linear, C: 0.1, Gamma: 0.1, Accuracy: 0.5971
# Features: (2,), Kernel: linear, C: 0.1, Gamma: 1, Accuracy: 0.5971
# Features: (2,), Kernel: linear, C: 0.1, Gamma: 10, Accuracy: 0.5971
# Features: (2,), Kernel: linear, C: 1, Gamma: 0.01, Accuracy: 0.5971
# Features: (2,), Kernel: linear, C: 1, Gamma: 0.1, Accuracy: 0.5971
# Features: (2,), Kernel: linear, C: 1, Gamma: 1, Accuracy: 0.5971
# Features: (2,), Kernel: linear, C: 1, Gamma: 10, Accuracy: 0.5971
# Features: (2,), Kernel: linear, C: 10, Gamma: 0.01, Accuracy: 0.5971
# Features: (2,), Kernel: linear, C: 10, Gamma: 0.1, Accuracy: 0.5971
# Features: (2,), Kernel: linear, C: 10, Gamma: 1, Accuracy: 0.5971
# Features: (2,), Kernel: linear, C: 10, Gamma: 10, Accuracy: 0.5971
# Features: (2,), Kernel: linear, C: 100, Gamma: 0.01, Accuracy: 0.5971
# Features: (2,), Kernel: linear, C: 100, Gamma: 0.1, Accuracy: 0.5971
# Features: (2,), Kernel: linear, C: 100, Gamma: 1, Accuracy: 0.5971
# Features: (2,), Kernel: linear, C: 100, Gamma: 10, Accuracy: 0.5971
# Features: (2,), Kernel: rbf, C: 0.1, Gamma: 0.01, Accuracy: 0.5558
# Features: (2,), Kernel: rbf, C: 0.1, Gamma: 0.1, Accuracy: 0.6068
# Features: (2,), Kernel: rbf, C: 0.1, Gamma: 1, Accuracy: 0.5971
# Features: (2,), Kernel: rbf, C: 0.1, Gamma: 10, Accuracy: 0.6602
# Features: (2,), Kernel: rbf, C: 1, Gamma: 0.01, Accuracy: 0.5898
# Features: (2,), Kernel: rbf, C: 1, Gamma: 0.1, Accuracy: 0.6044
# Features: (2,), Kernel: rbf, C: 1, Gamma: 1, Accuracy: 0.6019
# Features: (2,), Kernel: rbf, C: 1, Gamma: 10, Accuracy: 0.6699
# Features: (2,), Kernel: rbf, C: 10, Gamma: 0.01, Accuracy: 0.6044
# Features: (2,), Kernel: rbf, C: 10, Gamma: 0.1, Accuracy: 0.6044
# Features: (2,), Kernel: rbf, C: 10, Gamma: 1, Accuracy: 0.6286
# Features: (2,), Kernel: rbf, C: 10, Gamma: 10, Accuracy: 0.6723
# Features: (2,), Kernel: rbf, C: 100, Gamma: 0.01, Accuracy: 0.6019
# Features: (2,), Kernel: rbf, C: 100, Gamma: 0.1, Accuracy: 0.6044
# Features: (2,), Kernel: rbf, C: 100, Gamma: 1, Accuracy: 0.6383
# Features: (2,), Kernel: rbf, C: 100, Gamma: 10, Accuracy: 0.6626
# Features: (2,), Kernel: poly, C: 0.1, Gamma: 0.01, Accuracy: 0.5558
# Features: (2,), Kernel: poly, C: 0.1, Gamma: 0.1, Accuracy: 0.5777
# Features: (2,), Kernel: poly, C: 0.1, Gamma: 1, Accuracy: 0.6238
# Features: (2,), Kernel: poly, C: 0.1, Gamma: 10, Accuracy: 0.6238
# Features: (2,), Kernel: poly, C: 1, Gamma: 0.01, Accuracy: 0.5558
# Features: (2,), Kernel: poly, C: 1, Gamma: 0.1, Accuracy: 0.6044
# Features: (2,), Kernel: poly, C: 1, Gamma: 1, Accuracy: 0.6238
# Features: (2,), Kernel: poly, C: 1, Gamma: 10, Accuracy: 0.6238
# Features: (2,), Kernel: poly, C: 10, Gamma: 0.01, Accuracy: 0.5558
# Features: (2,), Kernel: poly, C: 10, Gamma: 0.1, Accuracy: 0.6214
# Features: (2,), Kernel: poly, C: 10, Gamma: 1, Accuracy: 0.6238
# Features: (2,), Kernel: poly, C: 10, Gamma: 10, Accuracy: 0.6238
# Features: (2,), Kernel: poly, C: 100, Gamma: 0.01, Accuracy: 0.5777
# Features: (2,), Kernel: poly, C: 100, Gamma: 0.1, Accuracy: 0.6238
# Features: (2,), Kernel: poly, C: 100, Gamma: 1, Accuracy: 0.6238
# Features: (2,), Kernel: poly, C: 100, Gamma: 10, Accuracy: 0.6068
# Features: (3,), Kernel: linear, C: 0.1, Gamma: 0.01, Accuracy: 0.5558
# Features: (3,), Kernel: linear, C: 0.1, Gamma: 0.1, Accuracy: 0.5558
# Features: (3,), Kernel: linear, C: 0.1, Gamma: 1, Accuracy: 0.5558
# Features: (3,), Kernel: linear, C: 0.1, Gamma: 10, Accuracy: 0.5558
# Features: (3,), Kernel: linear, C: 1, Gamma: 0.01, Accuracy: 0.5558
# Features: (3,), Kernel: linear, C: 1, Gamma: 0.1, Accuracy: 0.5558
# Features: (3,), Kernel: linear, C: 1, Gamma: 1, Accuracy: 0.5558
# Features: (3,), Kernel: linear, C: 1, Gamma: 10, Accuracy: 0.5558
# Features: (3,), Kernel: linear, C: 10, Gamma: 0.01, Accuracy: 0.5558
# Features: (3,), Kernel: linear, C: 10, Gamma: 0.1, Accuracy: 0.5558
# Features: (3,), Kernel: linear, C: 10, Gamma: 1, Accuracy: 0.5558
# Features: (3,), Kernel: linear, C: 10, Gamma: 10, Accuracy: 0.5558
# Features: (3,), Kernel: linear, C: 100, Gamma: 0.01, Accuracy: 0.5558
# Features: (3,), Kernel: linear, C: 100, Gamma: 0.1, Accuracy: 0.5558
# Features: (3,), Kernel: linear, C: 100, Gamma: 1, Accuracy: 0.5558
# Features: (3,), Kernel: linear, C: 100, Gamma: 10, Accuracy: 0.5558
# Features: (3,), Kernel: rbf, C: 0.1, Gamma: 0.01, Accuracy: 0.5558
# Features: (3,), Kernel: rbf, C: 0.1, Gamma: 0.1, Accuracy: 0.5558
# Features: (3,), Kernel: rbf, C: 0.1, Gamma: 1, Accuracy: 0.5558
# Features: (3,), Kernel: rbf, C: 0.1, Gamma: 10, Accuracy: 0.5704
# Features: (3,), Kernel: rbf, C: 1, Gamma: 0.01, Accuracy: 0.5558
# Features: (3,), Kernel: rbf, C: 1, Gamma: 0.1, Accuracy: 0.5558
# Features: (3,), Kernel: rbf, C: 1, Gamma: 1, Accuracy: 0.5680
# Features: (3,), Kernel: rbf, C: 1, Gamma: 10, Accuracy: 0.5801
# Features: (3,), Kernel: rbf, C: 10, Gamma: 0.01, Accuracy: 0.5558
# Features: (3,), Kernel: rbf, C: 10, Gamma: 0.1, Accuracy: 0.5558
# Features: (3,), Kernel: rbf, C: 10, Gamma: 1, Accuracy: 0.5704
# Features: (3,), Kernel: rbf, C: 10, Gamma: 10, Accuracy: 0.5607
# Features: (3,), Kernel: rbf, C: 100, Gamma: 0.01, Accuracy: 0.5558
# Features: (3,), Kernel: rbf, C: 100, Gamma: 0.1, Accuracy: 0.5558
# Features: (3,), Kernel: rbf, C: 100, Gamma: 1, Accuracy: 0.5850
# Features: (3,), Kernel: rbf, C: 100, Gamma: 10, Accuracy: 0.5631
# Features: (3,), Kernel: poly, C: 0.1, Gamma: 0.01, Accuracy: 0.5558
# Features: (3,), Kernel: poly, C: 0.1, Gamma: 0.1, Accuracy: 0.5558
# Features: (3,), Kernel: poly, C: 0.1, Gamma: 1, Accuracy: 0.5558
# Features: (3,), Kernel: poly, C: 0.1, Gamma: 10, Accuracy: 0.5558
# Features: (3,), Kernel: poly, C: 1, Gamma: 0.01, Accuracy: 0.5558
# Features: (3,), Kernel: poly, C: 1, Gamma: 0.1, Accuracy: 0.5558
# Features: (3,), Kernel: poly, C: 1, Gamma: 1, Accuracy: 0.5558
# Features: (3,), Kernel: poly, C: 1, Gamma: 10, Accuracy: 0.5558
# Features: (3,), Kernel: poly, C: 10, Gamma: 0.01, Accuracy: 0.5558
# Features: (3,), Kernel: poly, C: 10, Gamma: 0.1, Accuracy: 0.5558
# Features: (3,), Kernel: poly, C: 10, Gamma: 1, Accuracy: 0.5558
# Features: (3,), Kernel: poly, C: 10, Gamma: 10, Accuracy: 0.5558
# Features: (3,), Kernel: poly, C: 100, Gamma: 0.01, Accuracy: 0.5558
# Features: (3,), Kernel: poly, C: 100, Gamma: 0.1, Accuracy: 0.5558
# Features: (3,), Kernel: poly, C: 100, Gamma: 1, Accuracy: 0.5558
# Features: (3,), Kernel: poly, C: 100, Gamma: 10, Accuracy: 0.5558
# Features: (0, 1), Kernel: linear, C: 0.1, Gamma: 0.01, Accuracy: 0.8786
# Features: (0, 1), Kernel: linear, C: 0.1, Gamma: 0.1, Accuracy: 0.8786
# Features: (0, 1), Kernel: linear, C: 0.1, Gamma: 1, Accuracy: 0.8786
# Features: (0, 1), Kernel: linear, C: 0.1, Gamma: 10, Accuracy: 0.8786
# Features: (0, 1), Kernel: linear, C: 1, Gamma: 0.01, Accuracy: 0.8714
# Features: (0, 1), Kernel: linear, C: 1, Gamma: 0.1, Accuracy: 0.8714
# Features: (0, 1), Kernel: linear, C: 1, Gamma: 1, Accuracy: 0.8714
# Features: (0, 1), Kernel: linear, C: 1, Gamma: 10, Accuracy: 0.8714
# Features: (0, 1), Kernel: linear, C: 10, Gamma: 0.01, Accuracy: 0.8714
# Features: (0, 1), Kernel: linear, C: 10, Gamma: 0.1, Accuracy: 0.8714
# Features: (0, 1), Kernel: linear, C: 10, Gamma: 1, Accuracy: 0.8714
# Features: (0, 1), Kernel: linear, C: 10, Gamma: 10, Accuracy: 0.8714
# Features: (0, 1), Kernel: linear, C: 100, Gamma: 0.01, Accuracy: 0.8714
# Features: (0, 1), Kernel: linear, C: 100, Gamma: 0.1, Accuracy: 0.8714
# Features: (0, 1), Kernel: linear, C: 100, Gamma: 1, Accuracy: 0.8714
# Features: (0, 1), Kernel: linear, C: 100, Gamma: 10, Accuracy: 0.8714
# Features: (0, 1), Kernel: rbf, C: 0.1, Gamma: 0.01, Accuracy: 0.8714
# Features: (0, 1), Kernel: rbf, C: 0.1, Gamma: 0.1, Accuracy: 0.8908
# Features: (0, 1), Kernel: rbf, C: 0.1, Gamma: 1, Accuracy: 0.9272
# Features: (0, 1), Kernel: rbf, C: 0.1, Gamma: 10, Accuracy: 0.9272
# Features: (0, 1), Kernel: rbf, C: 1, Gamma: 0.01, Accuracy: 0.8883
# Features: (0, 1), Kernel: rbf, C: 1, Gamma: 0.1, Accuracy: 0.9078
# Features: (0, 1), Kernel: rbf, C: 1, Gamma: 1, Accuracy: 0.9272
# Features: (0, 1), Kernel: rbf, C: 1, Gamma: 10, Accuracy: 0.9369
# Features: (0, 1), Kernel: rbf, C: 10, Gamma: 0.01, Accuracy: 0.8956
# Features: (0, 1), Kernel: rbf, C: 10, Gamma: 0.1, Accuracy: 0.9199
# Features: (0, 1), Kernel: rbf, C: 10, Gamma: 1, Accuracy: 0.9369
# Features: (0, 1), Kernel: rbf, C: 10, Gamma: 10, Accuracy: 0.9417
# Features: (0, 1), Kernel: rbf, C: 100, Gamma: 0.01, Accuracy: 0.9053
# Features: (0, 1), Kernel: rbf, C: 100, Gamma: 0.1, Accuracy: 0.9296
# Features: (0, 1), Kernel: rbf, C: 100, Gamma: 1, Accuracy: 0.9393
# Features: (0, 1), Kernel: rbf, C: 100, Gamma: 10, Accuracy: 0.9587
# Features: (0, 1), Kernel: poly, C: 0.1, Gamma: 0.01, Accuracy: 0.5558
# Features: (0, 1), Kernel: poly, C: 0.1, Gamma: 0.1, Accuracy: 0.6408
# Features: (0, 1), Kernel: poly, C: 0.1, Gamma: 1, Accuracy: 0.8180
# Features: (0, 1), Kernel: poly, C: 0.1, Gamma: 10, Accuracy: 0.8374
# Features: (0, 1), Kernel: poly, C: 1, Gamma: 0.01, Accuracy: 0.5558
# Features: (0, 1), Kernel: poly, C: 1, Gamma: 0.1, Accuracy: 0.7427
# Features: (0, 1), Kernel: poly, C: 1, Gamma: 1, Accuracy: 0.8398
# Features: (0, 1), Kernel: poly, C: 1, Gamma: 10, Accuracy: 0.8374
# Features: (0, 1), Kernel: poly, C: 10, Gamma: 0.01, Accuracy: 0.5558
# Features: (0, 1), Kernel: poly, C: 10, Gamma: 0.1, Accuracy: 0.8204
# Features: (0, 1), Kernel: poly, C: 10, Gamma: 1, Accuracy: 0.8374
# Features: (0, 1), Kernel: poly, C: 10, Gamma: 10, Accuracy: 0.8374
# Features: (0, 1), Kernel: poly, C: 100, Gamma: 0.01, Accuracy: 0.6408
# Features: (0, 1), Kernel: poly, C: 100, Gamma: 0.1, Accuracy: 0.8180
# Features: (0, 1), Kernel: poly, C: 100, Gamma: 1, Accuracy: 0.8374
# Features: (0, 1), Kernel: poly, C: 100, Gamma: 10, Accuracy: 0.8374
# Features: (0, 2), Kernel: linear, C: 0.1, Gamma: 0.01, Accuracy: 0.8617
# Features: (0, 2), Kernel: linear, C: 0.1, Gamma: 0.1, Accuracy: 0.8617
# Features: (0, 2), Kernel: linear, C: 0.1, Gamma: 1, Accuracy: 0.8617
# Features: (0, 2), Kernel: linear, C: 0.1, Gamma: 10, Accuracy: 0.8617
# Features: (0, 2), Kernel: linear, C: 1, Gamma: 0.01, Accuracy: 0.8519
# Features: (0, 2), Kernel: linear, C: 1, Gamma: 0.1, Accuracy: 0.8519
# Features: (0, 2), Kernel: linear, C: 1, Gamma: 1, Accuracy: 0.8519
# Features: (0, 2), Kernel: linear, C: 1, Gamma: 10, Accuracy: 0.8519
# Features: (0, 2), Kernel: linear, C: 10, Gamma: 0.01, Accuracy: 0.8519
# Features: (0, 2), Kernel: linear, C: 10, Gamma: 0.1, Accuracy: 0.8519
# Features: (0, 2), Kernel: linear, C: 10, Gamma: 1, Accuracy: 0.8519
# Features: (0, 2), Kernel: linear, C: 10, Gamma: 10, Accuracy: 0.8519
# Features: (0, 2), Kernel: linear, C: 100, Gamma: 0.01, Accuracy: 0.8544
# Features: (0, 2), Kernel: linear, C: 100, Gamma: 0.1, Accuracy: 0.8544
# Features: (0, 2), Kernel: linear, C: 100, Gamma: 1, Accuracy: 0.8544
# Features: (0, 2), Kernel: linear, C: 100, Gamma: 10, Accuracy: 0.8544
# Features: (0, 2), Kernel: rbf, C: 0.1, Gamma: 0.01, Accuracy: 0.8325
# Features: (0, 2), Kernel: rbf, C: 0.1, Gamma: 0.1, Accuracy: 0.8714
# Features: (0, 2), Kernel: rbf, C: 0.1, Gamma: 1, Accuracy: 0.8835
# Features: (0, 2), Kernel: rbf, C: 0.1, Gamma: 10, Accuracy: 0.8859
# Features: (0, 2), Kernel: rbf, C: 1, Gamma: 0.01, Accuracy: 0.8617
# Features: (0, 2), Kernel: rbf, C: 1, Gamma: 0.1, Accuracy: 0.8738
# Features: (0, 2), Kernel: rbf, C: 1, Gamma: 1, Accuracy: 0.8932
# Features: (0, 2), Kernel: rbf, C: 1, Gamma: 10, Accuracy: 0.8908
# Features: (0, 2), Kernel: rbf, C: 10, Gamma: 0.01, Accuracy: 0.8738
# Features: (0, 2), Kernel: rbf, C: 10, Gamma: 0.1, Accuracy: 0.8738
# Features: (0, 2), Kernel: rbf, C: 10, Gamma: 1, Accuracy: 0.8932
# Features: (0, 2), Kernel: rbf, C: 10, Gamma: 10, Accuracy: 0.8981
# Features: (0, 2), Kernel: rbf, C: 100, Gamma: 0.01, Accuracy: 0.8714
# Features: (0, 2), Kernel: rbf, C: 100, Gamma: 0.1, Accuracy: 0.8883
# Features: (0, 2), Kernel: rbf, C: 100, Gamma: 1, Accuracy: 0.8908
# Features: (0, 2), Kernel: rbf, C: 100, Gamma: 10, Accuracy: 0.9005
# Features: (0, 2), Kernel: poly, C: 0.1, Gamma: 0.01, Accuracy: 0.5558
# Features: (0, 2), Kernel: poly, C: 0.1, Gamma: 0.1, Accuracy: 0.6189
# Features: (0, 2), Kernel: poly, C: 0.1, Gamma: 1, Accuracy: 0.8277
# Features: (0, 2), Kernel: poly, C: 0.1, Gamma: 10, Accuracy: 0.8301
# Features: (0, 2), Kernel: poly, C: 1, Gamma: 0.01, Accuracy: 0.5558
# Features: (0, 2), Kernel: poly, C: 1, Gamma: 0.1, Accuracy: 0.7087
# Features: (0, 2), Kernel: poly, C: 1, Gamma: 1, Accuracy: 0.8301
# Features: (0, 2), Kernel: poly, C: 1, Gamma: 10, Accuracy: 0.8301
# Features: (0, 2), Kernel: poly, C: 10, Gamma: 0.01, Accuracy: 0.5583
# Features: (0, 2), Kernel: poly, C: 10, Gamma: 0.1, Accuracy: 0.8325
# Features: (0, 2), Kernel: poly, C: 10, Gamma: 1, Accuracy: 0.8301
# Features: (0, 2), Kernel: poly, C: 10, Gamma: 10, Accuracy: 0.8301
# Features: (0, 2), Kernel: poly, C: 100, Gamma: 0.01, Accuracy: 0.6189
# Features: (0, 2), Kernel: poly, C: 100, Gamma: 0.1, Accuracy: 0.8277
# Features: (0, 2), Kernel: poly, C: 100, Gamma: 1, Accuracy: 0.8301
# Features: (0, 2), Kernel: poly, C: 100, Gamma: 10, Accuracy: 0.8301
# Features: (0, 3), Kernel: linear, C: 0.1, Gamma: 0.01, Accuracy: 0.8762
# Features: (0, 3), Kernel: linear, C: 0.1, Gamma: 0.1, Accuracy: 0.8762
# Features: (0, 3), Kernel: linear, C: 0.1, Gamma: 1, Accuracy: 0.8762
# Features: (0, 3), Kernel: linear, C: 0.1, Gamma: 10, Accuracy: 0.8762
# Features: (0, 3), Kernel: linear, C: 1, Gamma: 0.01, Accuracy: 0.8762
# Features: (0, 3), Kernel: linear, C: 1, Gamma: 0.1, Accuracy: 0.8762
# Features: (0, 3), Kernel: linear, C: 1, Gamma: 1, Accuracy: 0.8762
# Features: (0, 3), Kernel: linear, C: 1, Gamma: 10, Accuracy: 0.8762
# Features: (0, 3), Kernel: linear, C: 10, Gamma: 0.01, Accuracy: 0.8762
# Features: (0, 3), Kernel: linear, C: 10, Gamma: 0.1, Accuracy: 0.8762
# Features: (0, 3), Kernel: linear, C: 10, Gamma: 1, Accuracy: 0.8762
# Features: (0, 3), Kernel: linear, C: 10, Gamma: 10, Accuracy: 0.8762
# Features: (0, 3), Kernel: linear, C: 100, Gamma: 0.01, Accuracy: 0.8762
# Features: (0, 3), Kernel: linear, C: 100, Gamma: 0.1, Accuracy: 0.8762
# Features: (0, 3), Kernel: linear, C: 100, Gamma: 1, Accuracy: 0.8762
# Features: (0, 3), Kernel: linear, C: 100, Gamma: 10, Accuracy: 0.8762
# Features: (0, 3), Kernel: rbf, C: 0.1, Gamma: 0.01, Accuracy: 0.8398
# Features: (0, 3), Kernel: rbf, C: 0.1, Gamma: 0.1, Accuracy: 0.8714
# Features: (0, 3), Kernel: rbf, C: 0.1, Gamma: 1, Accuracy: 0.8786
# Features: (0, 3), Kernel: rbf, C: 0.1, Gamma: 10, Accuracy: 0.8883
# Features: (0, 3), Kernel: rbf, C: 1, Gamma: 0.01, Accuracy: 0.8762
# Features: (0, 3), Kernel: rbf, C: 1, Gamma: 0.1, Accuracy: 0.8714
# Features: (0, 3), Kernel: rbf, C: 1, Gamma: 1, Accuracy: 0.8786
# Features: (0, 3), Kernel: rbf, C: 1, Gamma: 10, Accuracy: 0.8981
# Features: (0, 3), Kernel: rbf, C: 10, Gamma: 0.01, Accuracy: 0.8689
# Features: (0, 3), Kernel: rbf, C: 10, Gamma: 0.1, Accuracy: 0.8811
# Features: (0, 3), Kernel: rbf, C: 10, Gamma: 1, Accuracy: 0.8883
# Features: (0, 3), Kernel: rbf, C: 10, Gamma: 10, Accuracy: 0.9005
# Features: (0, 3), Kernel: rbf, C: 100, Gamma: 0.01, Accuracy: 0.8689
# Features: (0, 3), Kernel: rbf, C: 100, Gamma: 0.1, Accuracy: 0.8811
# Features: (0, 3), Kernel: rbf, C: 100, Gamma: 1, Accuracy: 0.8883
# Features: (0, 3), Kernel: rbf, C: 100, Gamma: 10, Accuracy: 0.9029
# Features: (0, 3), Kernel: poly, C: 0.1, Gamma: 0.01, Accuracy: 0.5558
# Features: (0, 3), Kernel: poly, C: 0.1, Gamma: 0.1, Accuracy: 0.5850
# Features: (0, 3), Kernel: poly, C: 0.1, Gamma: 1, Accuracy: 0.8204
# Features: (0, 3), Kernel: poly, C: 0.1, Gamma: 10, Accuracy: 0.8252
# Features: (0, 3), Kernel: poly, C: 1, Gamma: 0.01, Accuracy: 0.5558
# Features: (0, 3), Kernel: poly, C: 1, Gamma: 0.1, Accuracy: 0.7524
# Features: (0, 3), Kernel: poly, C: 1, Gamma: 1, Accuracy: 0.8252
# Features: (0, 3), Kernel: poly, C: 1, Gamma: 10, Accuracy: 0.8252
# Features: (0, 3), Kernel: poly, C: 10, Gamma: 0.01, Accuracy: 0.5558
# Features: (0, 3), Kernel: poly, C: 10, Gamma: 0.1, Accuracy: 0.8301
# Features: (0, 3), Kernel: poly, C: 10, Gamma: 1, Accuracy: 0.8252
# Features: (0, 3), Kernel: poly, C: 10, Gamma: 10, Accuracy: 0.8252
# Features: (0, 3), Kernel: poly, C: 100, Gamma: 0.01, Accuracy: 0.5850
# Features: (0, 3), Kernel: poly, C: 100, Gamma: 0.1, Accuracy: 0.8204
# Features: (0, 3), Kernel: poly, C: 100, Gamma: 1, Accuracy: 0.8252
# Features: (0, 3), Kernel: poly, C: 100, Gamma: 10, Accuracy: 0.8131
# Features: (1, 2), Kernel: linear, C: 0.1, Gamma: 0.01, Accuracy: 0.7816
# Features: (1, 2), Kernel: linear, C: 0.1, Gamma: 0.1, Accuracy: 0.7816
# Features: (1, 2), Kernel: linear, C: 0.1, Gamma: 1, Accuracy: 0.7816
# Features: (1, 2), Kernel: linear, C: 0.1, Gamma: 10, Accuracy: 0.7816
# Features: (1, 2), Kernel: linear, C: 1, Gamma: 0.01, Accuracy: 0.7816
# Features: (1, 2), Kernel: linear, C: 1, Gamma: 0.1, Accuracy: 0.7816
# Features: (1, 2), Kernel: linear, C: 1, Gamma: 1, Accuracy: 0.7816
# Features: (1, 2), Kernel: linear, C: 1, Gamma: 10, Accuracy: 0.7816
# Features: (1, 2), Kernel: linear, C: 10, Gamma: 0.01, Accuracy: 0.7816
# Features: (1, 2), Kernel: linear, C: 10, Gamma: 0.1, Accuracy: 0.7816
# Features: (1, 2), Kernel: linear, C: 10, Gamma: 1, Accuracy: 0.7816
# Features: (1, 2), Kernel: linear, C: 10, Gamma: 10, Accuracy: 0.7816
# Features: (1, 2), Kernel: linear, C: 100, Gamma: 0.01, Accuracy: 0.7816
# Features: (1, 2), Kernel: linear, C: 100, Gamma: 0.1, Accuracy: 0.7816
# Features: (1, 2), Kernel: linear, C: 100, Gamma: 1, Accuracy: 0.7816
# Features: (1, 2), Kernel: linear, C: 100, Gamma: 10, Accuracy: 0.7816
# Features: (1, 2), Kernel: rbf, C: 0.1, Gamma: 0.01, Accuracy: 0.6117
# Features: (1, 2), Kernel: rbf, C: 0.1, Gamma: 0.1, Accuracy: 0.7816
# Features: (1, 2), Kernel: rbf, C: 0.1, Gamma: 1, Accuracy: 0.8107
# Features: (1, 2), Kernel: rbf, C: 0.1, Gamma: 10, Accuracy: 0.8568
# Features: (1, 2), Kernel: rbf, C: 1, Gamma: 0.01, Accuracy: 0.7767
# Features: (1, 2), Kernel: rbf, C: 1, Gamma: 0.1, Accuracy: 0.7743
# Features: (1, 2), Kernel: rbf, C: 1, Gamma: 1, Accuracy: 0.8252
# Features: (1, 2), Kernel: rbf, C: 1, Gamma: 10, Accuracy: 0.8592
# Features: (1, 2), Kernel: rbf, C: 10, Gamma: 0.01, Accuracy: 0.7816
# Features: (1, 2), Kernel: rbf, C: 10, Gamma: 0.1, Accuracy: 0.8277
# Features: (1, 2), Kernel: rbf, C: 10, Gamma: 1, Accuracy: 0.8568
# Features: (1, 2), Kernel: rbf, C: 10, Gamma: 10, Accuracy: 0.8738
# Features: (1, 2), Kernel: rbf, C: 100, Gamma: 0.01, Accuracy: 0.7694
# Features: (1, 2), Kernel: rbf, C: 100, Gamma: 0.1, Accuracy: 0.8398
# Features: (1, 2), Kernel: rbf, C: 100, Gamma: 1, Accuracy: 0.8689
# Features: (1, 2), Kernel: rbf, C: 100, Gamma: 10, Accuracy: 0.8665
# Features: (1, 2), Kernel: poly, C: 0.1, Gamma: 0.01, Accuracy: 0.5558
# Features: (1, 2), Kernel: poly, C: 0.1, Gamma: 0.1, Accuracy: 0.6262
# Features: (1, 2), Kernel: poly, C: 0.1, Gamma: 1, Accuracy: 0.7306
# Features: (1, 2), Kernel: poly, C: 0.1, Gamma: 10, Accuracy: 0.7840
# Features: (1, 2), Kernel: poly, C: 1, Gamma: 0.01, Accuracy: 0.5558
# Features: (1, 2), Kernel: poly, C: 1, Gamma: 0.1, Accuracy: 0.6456
# Features: (1, 2), Kernel: poly, C: 1, Gamma: 1, Accuracy: 0.7500
# Features: (1, 2), Kernel: poly, C: 1, Gamma: 10, Accuracy: 0.7840
# Features: (1, 2), Kernel: poly, C: 10, Gamma: 0.01, Accuracy: 0.5777
# Features: (1, 2), Kernel: poly, C: 10, Gamma: 0.1, Accuracy: 0.6772
# Features: (1, 2), Kernel: poly, C: 10, Gamma: 1, Accuracy: 0.7791
# Features: (1, 2), Kernel: poly, C: 10, Gamma: 10, Accuracy: 0.7816
# Features: (1, 2), Kernel: poly, C: 100, Gamma: 0.01, Accuracy: 0.6262
# Features: (1, 2), Kernel: poly, C: 100, Gamma: 0.1, Accuracy: 0.7306
# Features: (1, 2), Kernel: poly, C: 100, Gamma: 1, Accuracy: 0.7840
# Features: (1, 2), Kernel: poly, C: 100, Gamma: 10, Accuracy: 0.7791
# Features: (1, 3), Kernel: linear, C: 0.1, Gamma: 0.01, Accuracy: 0.7015
# Features: (1, 3), Kernel: linear, C: 0.1, Gamma: 0.1, Accuracy: 0.7015
# Features: (1, 3), Kernel: linear, C: 0.1, Gamma: 1, Accuracy: 0.7015
# Features: (1, 3), Kernel: linear, C: 0.1, Gamma: 10, Accuracy: 0.7015
# Features: (1, 3), Kernel: linear, C: 1, Gamma: 0.01, Accuracy: 0.7136
# Features: (1, 3), Kernel: linear, C: 1, Gamma: 0.1, Accuracy: 0.7136
# Features: (1, 3), Kernel: linear, C: 1, Gamma: 1, Accuracy: 0.7136
# Features: (1, 3), Kernel: linear, C: 1, Gamma: 10, Accuracy: 0.7136
# Features: (1, 3), Kernel: linear, C: 10, Gamma: 0.01, Accuracy: 0.7112
# Features: (1, 3), Kernel: linear, C: 10, Gamma: 0.1, Accuracy: 0.7112
# Features: (1, 3), Kernel: linear, C: 10, Gamma: 1, Accuracy: 0.7112
# Features: (1, 3), Kernel: linear, C: 10, Gamma: 10, Accuracy: 0.7112
# Features: (1, 3), Kernel: linear, C: 100, Gamma: 0.01, Accuracy: 0.7136
# Features: (1, 3), Kernel: linear, C: 100, Gamma: 0.1, Accuracy: 0.7136
# Features: (1, 3), Kernel: linear, C: 100, Gamma: 1, Accuracy: 0.7136
# Features: (1, 3), Kernel: linear, C: 100, Gamma: 10, Accuracy: 0.7136
# Features: (1, 3), Kernel: rbf, C: 0.1, Gamma: 0.01, Accuracy: 0.6141
# Features: (1, 3), Kernel: rbf, C: 0.1, Gamma: 0.1, Accuracy: 0.7549
# Features: (1, 3), Kernel: rbf, C: 0.1, Gamma: 1, Accuracy: 0.8010
# Features: (1, 3), Kernel: rbf, C: 0.1, Gamma: 10, Accuracy: 0.8665
# Features: (1, 3), Kernel: rbf, C: 1, Gamma: 0.01, Accuracy: 0.6942
# Features: (1, 3), Kernel: rbf, C: 1, Gamma: 0.1, Accuracy: 0.7888
# Features: (1, 3), Kernel: rbf, C: 1, Gamma: 1, Accuracy: 0.8714
# Features: (1, 3), Kernel: rbf, C: 1, Gamma: 10, Accuracy: 0.8786
# Features: (1, 3), Kernel: rbf, C: 10, Gamma: 0.01, Accuracy: 0.7597
# Features: (1, 3), Kernel: rbf, C: 10, Gamma: 0.1, Accuracy: 0.8107
# Features: (1, 3), Kernel: rbf, C: 10, Gamma: 1, Accuracy: 0.8689
# Features: (1, 3), Kernel: rbf, C: 10, Gamma: 10, Accuracy: 0.8811
# Features: (1, 3), Kernel: rbf, C: 100, Gamma: 0.01, Accuracy: 0.8010
# Features: (1, 3), Kernel: rbf, C: 100, Gamma: 0.1, Accuracy: 0.8301
# Features: (1, 3), Kernel: rbf, C: 100, Gamma: 1, Accuracy: 0.8738
# Features: (1, 3), Kernel: rbf, C: 100, Gamma: 10, Accuracy: 0.8689
# Features: (1, 3), Kernel: poly, C: 0.1, Gamma: 0.01, Accuracy: 0.5558
# Features: (1, 3), Kernel: poly, C: 0.1, Gamma: 0.1, Accuracy: 0.5777
# Features: (1, 3), Kernel: poly, C: 0.1, Gamma: 1, Accuracy: 0.6748
# Features: (1, 3), Kernel: poly, C: 0.1, Gamma: 10, Accuracy: 0.6772
# Features: (1, 3), Kernel: poly, C: 1, Gamma: 0.01, Accuracy: 0.5558
# Features: (1, 3), Kernel: poly, C: 1, Gamma: 0.1, Accuracy: 0.6748
# Features: (1, 3), Kernel: poly, C: 1, Gamma: 1, Accuracy: 0.6772
# Features: (1, 3), Kernel: poly, C: 1, Gamma: 10, Accuracy: 0.6772
# Features: (1, 3), Kernel: poly, C: 10, Gamma: 0.01, Accuracy: 0.5558
# Features: (1, 3), Kernel: poly, C: 10, Gamma: 0.1, Accuracy: 0.6650
# Features: (1, 3), Kernel: poly, C: 10, Gamma: 1, Accuracy: 0.6772
# Features: (1, 3), Kernel: poly, C: 10, Gamma: 10, Accuracy: 0.6748
# Features: (1, 3), Kernel: poly, C: 100, Gamma: 0.01, Accuracy: 0.5777
# Features: (1, 3), Kernel: poly, C: 100, Gamma: 0.1, Accuracy: 0.6748
# Features: (1, 3), Kernel: poly, C: 100, Gamma: 1, Accuracy: 0.6772
# Features: (1, 3), Kernel: poly, C: 100, Gamma: 10, Accuracy: 0.7063
# Features: (2, 3), Kernel: linear, C: 0.1, Gamma: 0.01, Accuracy: 0.6019
# Features: (2, 3), Kernel: linear, C: 0.1, Gamma: 0.1, Accuracy: 0.6019
# Features: (2, 3), Kernel: linear, C: 0.1, Gamma: 1, Accuracy: 0.6019
# Features: (2, 3), Kernel: linear, C: 0.1, Gamma: 10, Accuracy: 0.6019
# Features: (2, 3), Kernel: linear, C: 1, Gamma: 0.01, Accuracy: 0.6019
# Features: (2, 3), Kernel: linear, C: 1, Gamma: 0.1, Accuracy: 0.6019
# Features: (2, 3), Kernel: linear, C: 1, Gamma: 1, Accuracy: 0.6019
# Features: (2, 3), Kernel: linear, C: 1, Gamma: 10, Accuracy: 0.6019
# Features: (2, 3), Kernel: linear, C: 10, Gamma: 0.01, Accuracy: 0.5898
# Features: (2, 3), Kernel: linear, C: 10, Gamma: 0.1, Accuracy: 0.5898
# Features: (2, 3), Kernel: linear, C: 10, Gamma: 1, Accuracy: 0.5898
# Features: (2, 3), Kernel: linear, C: 10, Gamma: 10, Accuracy: 0.5898
# Features: (2, 3), Kernel: linear, C: 100, Gamma: 0.01, Accuracy: 0.5922
# Features: (2, 3), Kernel: linear, C: 100, Gamma: 0.1, Accuracy: 0.5922
# Features: (2, 3), Kernel: linear, C: 100, Gamma: 1, Accuracy: 0.5922
# Features: (2, 3), Kernel: linear, C: 100, Gamma: 10, Accuracy: 0.5922
# Features: (2, 3), Kernel: rbf, C: 0.1, Gamma: 0.01, Accuracy: 0.5558
# Features: (2, 3), Kernel: rbf, C: 0.1, Gamma: 0.1, Accuracy: 0.6092
# Features: (2, 3), Kernel: rbf, C: 0.1, Gamma: 1, Accuracy: 0.6092
# Features: (2, 3), Kernel: rbf, C: 0.1, Gamma: 10, Accuracy: 0.6238
# Features: (2, 3), Kernel: rbf, C: 1, Gamma: 0.01, Accuracy: 0.6092
# Features: (2, 3), Kernel: rbf, C: 1, Gamma: 0.1, Accuracy: 0.6019
# Features: (2, 3), Kernel: rbf, C: 1, Gamma: 1, Accuracy: 0.6286
# Features: (2, 3), Kernel: rbf, C: 1, Gamma: 10, Accuracy: 0.7063
# Features: (2, 3), Kernel: rbf, C: 10, Gamma: 0.01, Accuracy: 0.6044
# Features: (2, 3), Kernel: rbf, C: 10, Gamma: 0.1, Accuracy: 0.6068
# Features: (2, 3), Kernel: rbf, C: 10, Gamma: 1, Accuracy: 0.6820
# Features: (2, 3), Kernel: rbf, C: 10, Gamma: 10, Accuracy: 0.7136
# Features: (2, 3), Kernel: rbf, C: 100, Gamma: 0.01, Accuracy: 0.6044
# Features: (2, 3), Kernel: rbf, C: 100, Gamma: 0.1, Accuracy: 0.6141
# Features: (2, 3), Kernel: rbf, C: 100, Gamma: 1, Accuracy: 0.7039
# Features: (2, 3), Kernel: rbf, C: 100, Gamma: 10, Accuracy: 0.7063
# Features: (2, 3), Kernel: poly, C: 0.1, Gamma: 0.01, Accuracy: 0.5558
# Features: (2, 3), Kernel: poly, C: 0.1, Gamma: 0.1, Accuracy: 0.5777
# Features: (2, 3), Kernel: poly, C: 0.1, Gamma: 1, Accuracy: 0.6165
# Features: (2, 3), Kernel: poly, C: 0.1, Gamma: 10, Accuracy: 0.6165
# Features: (2, 3), Kernel: poly, C: 1, Gamma: 0.01, Accuracy: 0.5558
# Features: (2, 3), Kernel: poly, C: 1, Gamma: 0.1, Accuracy: 0.6068
# Features: (2, 3), Kernel: poly, C: 1, Gamma: 1, Accuracy: 0.6141
# Features: (2, 3), Kernel: poly, C: 1, Gamma: 10, Accuracy: 0.6165
# Features: (2, 3), Kernel: poly, C: 10, Gamma: 0.01, Accuracy: 0.5558
# Features: (2, 3), Kernel: poly, C: 10, Gamma: 0.1, Accuracy: 0.6141
# Features: (2, 3), Kernel: poly, C: 10, Gamma: 1, Accuracy: 0.6165
# Features: (2, 3), Kernel: poly, C: 10, Gamma: 10, Accuracy: 0.6141
# Features: (2, 3), Kernel: poly, C: 100, Gamma: 0.01, Accuracy: 0.5777
# Features: (2, 3), Kernel: poly, C: 100, Gamma: 0.1, Accuracy: 0.6165
# Features: (2, 3), Kernel: poly, C: 100, Gamma: 1, Accuracy: 0.6165
# Features: (2, 3), Kernel: poly, C: 100, Gamma: 10, Accuracy: 0.6117
# Features: (0, 1, 2), Kernel: linear, C: 0.1, Gamma: 0.01, Accuracy: 0.9854
# Features: (0, 1, 2), Kernel: linear, C: 0.1, Gamma: 0.1, Accuracy: 0.9854
# Features: (0, 1, 2), Kernel: linear, C: 0.1, Gamma: 1, Accuracy: 0.9854
# Features: (0, 1, 2), Kernel: linear, C: 0.1, Gamma: 10, Accuracy: 0.9854
# Features: (0, 1, 2), Kernel: linear, C: 1, Gamma: 0.01, Accuracy: 0.9854
# Features: (0, 1, 2), Kernel: linear, C: 1, Gamma: 0.1, Accuracy: 0.9854
# Features: (0, 1, 2), Kernel: linear, C: 1, Gamma: 1, Accuracy: 0.9854
# Features: (0, 1, 2), Kernel: linear, C: 1, Gamma: 10, Accuracy: 0.9854
# Features: (0, 1, 2), Kernel: linear, C: 10, Gamma: 0.01, Accuracy: 0.9879
# Features: (0, 1, 2), Kernel: linear, C: 10, Gamma: 0.1, Accuracy: 0.9879
# Features: (0, 1, 2), Kernel: linear, C: 10, Gamma: 1, Accuracy: 0.9879
# Features: (0, 1, 2), Kernel: linear, C: 10, Gamma: 10, Accuracy: 0.9879
# Features: (0, 1, 2), Kernel: linear, C: 100, Gamma: 0.01, Accuracy: 0.9879
# Features: (0, 1, 2), Kernel: linear, C: 100, Gamma: 0.1, Accuracy: 0.9879
# Features: (0, 1, 2), Kernel: linear, C: 100, Gamma: 1, Accuracy: 0.9879
# Features: (0, 1, 2), Kernel: linear, C: 100, Gamma: 10, Accuracy: 0.9879
# Features: (0, 1, 2), Kernel: rbf, C: 0.1, Gamma: 0.01, Accuracy: 0.9199
# Features: (0, 1, 2), Kernel: rbf, C: 0.1, Gamma: 0.1, Accuracy: 0.9854
# Features: (0, 1, 2), Kernel: rbf, C: 0.1, Gamma: 1, Accuracy: 0.9951
# Features: (0, 1, 2), Kernel: rbf, C: 0.1, Gamma: 10, Accuracy: 0.9879
# Features: (0, 1, 2), Kernel: rbf, C: 1, Gamma: 0.01, Accuracy: 0.9854
# Features: (0, 1, 2), Kernel: rbf, C: 1, Gamma: 0.1, Accuracy: 0.9951
# Features: (0, 1, 2), Kernel: rbf, C: 1, Gamma: 1, Accuracy: 1.0000
# Features: (0, 1, 2), Kernel: rbf, C: 1, Gamma: 10, Accuracy: 1.0000
# Features: (0, 1, 2), Kernel: rbf, C: 10, Gamma: 0.01, Accuracy: 0.9879
# Features: (0, 1, 2), Kernel: rbf, C: 10, Gamma: 0.1, Accuracy: 1.0000
# Features: (0, 1, 2), Kernel: rbf, C: 10, Gamma: 1, Accuracy: 1.0000
# Features: (0, 1, 2), Kernel: rbf, C: 10, Gamma: 10, Accuracy: 1.0000
# Features: (0, 1, 2), Kernel: rbf, C: 100, Gamma: 0.01, Accuracy: 1.0000
# Features: (0, 1, 2), Kernel: rbf, C: 100, Gamma: 0.1, Accuracy: 1.0000
# Features: (0, 1, 2), Kernel: rbf, C: 100, Gamma: 1, Accuracy: 1.0000
# Features: (0, 1, 2), Kernel: rbf, C: 100, Gamma: 10, Accuracy: 1.0000
# Features: (0, 1, 2), Kernel: poly, C: 0.1, Gamma: 0.01, Accuracy: 0.5558
# Features: (0, 1, 2), Kernel: poly, C: 0.1, Gamma: 0.1, Accuracy: 0.6553
# Features: (0, 1, 2), Kernel: poly, C: 0.1, Gamma: 1, Accuracy: 0.9660
# Features: (0, 1, 2), Kernel: poly, C: 0.1, Gamma: 10, Accuracy: 1.0000
# Features: (0, 1, 2), Kernel: poly, C: 1, Gamma: 0.01, Accuracy: 0.5558
# Features: (0, 1, 2), Kernel: poly, C: 1, Gamma: 0.1, Accuracy: 0.7718
# Features: (0, 1, 2), Kernel: poly, C: 1, Gamma: 1, Accuracy: 0.9879
# Features: (0, 1, 2), Kernel: poly, C: 1, Gamma: 10, Accuracy: 1.0000
# Features: (0, 1, 2), Kernel: poly, C: 10, Gamma: 0.01, Accuracy: 0.5777
# Features: (0, 1, 2), Kernel: poly, C: 10, Gamma: 0.1, Accuracy: 0.9636
# Features: (0, 1, 2), Kernel: poly, C: 10, Gamma: 1, Accuracy: 0.9927
# Features: (0, 1, 2), Kernel: poly, C: 10, Gamma: 10, Accuracy: 1.0000
# Features: (0, 1, 2), Kernel: poly, C: 100, Gamma: 0.01, Accuracy: 0.6553
# Features: (0, 1, 2), Kernel: poly, C: 100, Gamma: 0.1, Accuracy: 0.9660
# Features: (0, 1, 2), Kernel: poly, C: 100, Gamma: 1, Accuracy: 1.0000
# Features: (0, 1, 2), Kernel: poly, C: 100, Gamma: 10, Accuracy: 1.0000
# Features: (0, 1, 3), Kernel: linear, C: 0.1, Gamma: 0.01, Accuracy: 0.8786
# Features: (0, 1, 3), Kernel: linear, C: 0.1, Gamma: 0.1, Accuracy: 0.8786
# Features: (0, 1, 3), Kernel: linear, C: 0.1, Gamma: 1, Accuracy: 0.8786
# Features: (0, 1, 3), Kernel: linear, C: 0.1, Gamma: 10, Accuracy: 0.8786
# Features: (0, 1, 3), Kernel: linear, C: 1, Gamma: 0.01, Accuracy: 0.8714
# Features: (0, 1, 3), Kernel: linear, C: 1, Gamma: 0.1, Accuracy: 0.8714
# Features: (0, 1, 3), Kernel: linear, C: 1, Gamma: 1, Accuracy: 0.8714
# Features: (0, 1, 3), Kernel: linear, C: 1, Gamma: 10, Accuracy: 0.8714
# Features: (0, 1, 3), Kernel: linear, C: 10, Gamma: 0.01, Accuracy: 0.8714
# Features: (0, 1, 3), Kernel: linear, C: 10, Gamma: 0.1, Accuracy: 0.8714
# Features: (0, 1, 3), Kernel: linear, C: 10, Gamma: 1, Accuracy: 0.8714
# Features: (0, 1, 3), Kernel: linear, C: 10, Gamma: 10, Accuracy: 0.8714
# Features: (0, 1, 3), Kernel: linear, C: 100, Gamma: 0.01, Accuracy: 0.8714
# Features: (0, 1, 3), Kernel: linear, C: 100, Gamma: 0.1, Accuracy: 0.8714
# Features: (0, 1, 3), Kernel: linear, C: 100, Gamma: 1, Accuracy: 0.8714
# Features: (0, 1, 3), Kernel: linear, C: 100, Gamma: 10, Accuracy: 0.8714
# Features: (0, 1, 3), Kernel: rbf, C: 0.1, Gamma: 0.01, Accuracy: 0.8714
# Features: (0, 1, 3), Kernel: rbf, C: 0.1, Gamma: 0.1, Accuracy: 0.8908
# Features: (0, 1, 3), Kernel: rbf, C: 0.1, Gamma: 1, Accuracy: 0.9466
# Features: (0, 1, 3), Kernel: rbf, C: 0.1, Gamma: 10, Accuracy: 0.9223
# Features: (0, 1, 3), Kernel: rbf, C: 1, Gamma: 0.01, Accuracy: 0.8859
# Features: (0, 1, 3), Kernel: rbf, C: 1, Gamma: 0.1, Accuracy: 0.9248
# Features: (0, 1, 3), Kernel: rbf, C: 1, Gamma: 1, Accuracy: 0.9563
# Features: (0, 1, 3), Kernel: rbf, C: 1, Gamma: 10, Accuracy: 0.9733
# Features: (0, 1, 3), Kernel: rbf, C: 10, Gamma: 0.01, Accuracy: 0.8981
# Features: (0, 1, 3), Kernel: rbf, C: 10, Gamma: 0.1, Accuracy: 0.9393
# Features: (0, 1, 3), Kernel: rbf, C: 10, Gamma: 1, Accuracy: 0.9806
# Features: (0, 1, 3), Kernel: rbf, C: 10, Gamma: 10, Accuracy: 0.9733
# Features: (0, 1, 3), Kernel: rbf, C: 100, Gamma: 0.01, Accuracy: 0.9199
# Features: (0, 1, 3), Kernel: rbf, C: 100, Gamma: 0.1, Accuracy: 0.9612
# Features: (0, 1, 3), Kernel: rbf, C: 100, Gamma: 1, Accuracy: 0.9806
# Features: (0, 1, 3), Kernel: rbf, C: 100, Gamma: 10, Accuracy: 0.9587
# Features: (0, 1, 3), Kernel: poly, C: 0.1, Gamma: 0.01, Accuracy: 0.5558
# Features: (0, 1, 3), Kernel: poly, C: 0.1, Gamma: 0.1, Accuracy: 0.6650
# Features: (0, 1, 3), Kernel: poly, C: 0.1, Gamma: 1, Accuracy: 0.8981
# Features: (0, 1, 3), Kernel: poly, C: 0.1, Gamma: 10, Accuracy: 0.9175
# Features: (0, 1, 3), Kernel: poly, C: 1, Gamma: 0.01, Accuracy: 0.5558
# Features: (0, 1, 3), Kernel: poly, C: 1, Gamma: 0.1, Accuracy: 0.7937
# Features: (0, 1, 3), Kernel: poly, C: 1, Gamma: 1, Accuracy: 0.9078
# Features: (0, 1, 3), Kernel: poly, C: 1, Gamma: 10, Accuracy: 0.9102
# Features: (0, 1, 3), Kernel: poly, C: 10, Gamma: 0.01, Accuracy: 0.5558
# Features: (0, 1, 3), Kernel: poly, C: 10, Gamma: 0.1, Accuracy: 0.8786
# Features: (0, 1, 3), Kernel: poly, C: 10, Gamma: 1, Accuracy: 0.9175
# Features: (0, 1, 3), Kernel: poly, C: 10, Gamma: 10, Accuracy: 0.9126
# Features: (0, 1, 3), Kernel: poly, C: 100, Gamma: 0.01, Accuracy: 0.6650
# Features: (0, 1, 3), Kernel: poly, C: 100, Gamma: 0.1, Accuracy: 0.8981
# Features: (0, 1, 3), Kernel: poly, C: 100, Gamma: 1, Accuracy: 0.9175
# Features: (0, 1, 3), Kernel: poly, C: 100, Gamma: 10, Accuracy: 0.9126
# Features: (0, 2, 3), Kernel: linear, C: 0.1, Gamma: 0.01, Accuracy: 0.9223
# Features: (0, 2, 3), Kernel: linear, C: 0.1, Gamma: 0.1, Accuracy: 0.9223
# Features: (0, 2, 3), Kernel: linear, C: 0.1, Gamma: 1, Accuracy: 0.9223
# Features: (0, 2, 3), Kernel: linear, C: 0.1, Gamma: 10, Accuracy: 0.9223
# Features: (0, 2, 3), Kernel: linear, C: 1, Gamma: 0.01, Accuracy: 0.9102
# Features: (0, 2, 3), Kernel: linear, C: 1, Gamma: 0.1, Accuracy: 0.9102
# Features: (0, 2, 3), Kernel: linear, C: 1, Gamma: 1, Accuracy: 0.9102
# Features: (0, 2, 3), Kernel: linear, C: 1, Gamma: 10, Accuracy: 0.9102
# Features: (0, 2, 3), Kernel: linear, C: 10, Gamma: 0.01, Accuracy: 0.9102
# Features: (0, 2, 3), Kernel: linear, C: 10, Gamma: 0.1, Accuracy: 0.9102
# Features: (0, 2, 3), Kernel: linear, C: 10, Gamma: 1, Accuracy: 0.9102
# Features: (0, 2, 3), Kernel: linear, C: 10, Gamma: 10, Accuracy: 0.9102
# Features: (0, 2, 3), Kernel: linear, C: 100, Gamma: 0.01, Accuracy: 0.9102
# Features: (0, 2, 3), Kernel: linear, C: 100, Gamma: 0.1, Accuracy: 0.9102
# Features: (0, 2, 3), Kernel: linear, C: 100, Gamma: 1, Accuracy: 0.9102
# Features: (0, 2, 3), Kernel: linear, C: 100, Gamma: 10, Accuracy: 0.9102
# Features: (0, 2, 3), Kernel: rbf, C: 0.1, Gamma: 0.01, Accuracy: 0.8350
# Features: (0, 2, 3), Kernel: rbf, C: 0.1, Gamma: 0.1, Accuracy: 0.9393
# Features: (0, 2, 3), Kernel: rbf, C: 0.1, Gamma: 1, Accuracy: 0.9684
# Features: (0, 2, 3), Kernel: rbf, C: 0.1, Gamma: 10, Accuracy: 0.9466
# Features: (0, 2, 3), Kernel: rbf, C: 1, Gamma: 0.01, Accuracy: 0.9223
# Features: (0, 2, 3), Kernel: rbf, C: 1, Gamma: 0.1, Accuracy: 0.9733
# Features: (0, 2, 3), Kernel: rbf, C: 1, Gamma: 1, Accuracy: 0.9782
# Features: (0, 2, 3), Kernel: rbf, C: 1, Gamma: 10, Accuracy: 0.9733
# Features: (0, 2, 3), Kernel: rbf, C: 10, Gamma: 0.01, Accuracy: 0.9539
# Features: (0, 2, 3), Kernel: rbf, C: 10, Gamma: 0.1, Accuracy: 0.9806
# Features: (0, 2, 3), Kernel: rbf, C: 10, Gamma: 1, Accuracy: 0.9757
# Features: (0, 2, 3), Kernel: rbf, C: 10, Gamma: 10, Accuracy: 0.9757
# Features: (0, 2, 3), Kernel: rbf, C: 100, Gamma: 0.01, Accuracy: 0.9709
# Features: (0, 2, 3), Kernel: rbf, C: 100, Gamma: 0.1, Accuracy: 0.9806
# Features: (0, 2, 3), Kernel: rbf, C: 100, Gamma: 1, Accuracy: 0.9733
# Features: (0, 2, 3), Kernel: rbf, C: 100, Gamma: 10, Accuracy: 0.9709
# Features: (0, 2, 3), Kernel: poly, C: 0.1, Gamma: 0.01, Accuracy: 0.5558
# Features: (0, 2, 3), Kernel: poly, C: 0.1, Gamma: 0.1, Accuracy: 0.6311
# Features: (0, 2, 3), Kernel: poly, C: 0.1, Gamma: 1, Accuracy: 0.9369
# Features: (0, 2, 3), Kernel: poly, C: 0.1, Gamma: 10, Accuracy: 0.9466
# Features: (0, 2, 3), Kernel: poly, C: 1, Gamma: 0.01, Accuracy: 0.5558
# Features: (0, 2, 3), Kernel: poly, C: 1, Gamma: 0.1, Accuracy: 0.7743
# Features: (0, 2, 3), Kernel: poly, C: 1, Gamma: 1, Accuracy: 0.9515
# Features: (0, 2, 3), Kernel: poly, C: 1, Gamma: 10, Accuracy: 0.9466
# Features: (0, 2, 3), Kernel: poly, C: 10, Gamma: 0.01, Accuracy: 0.5583
# Features: (0, 2, 3), Kernel: poly, C: 10, Gamma: 0.1, Accuracy: 0.9345
# Features: (0, 2, 3), Kernel: poly, C: 10, Gamma: 1, Accuracy: 0.9490
# Features: (0, 2, 3), Kernel: poly, C: 10, Gamma: 10, Accuracy: 0.9466
# Features: (0, 2, 3), Kernel: poly, C: 100, Gamma: 0.01, Accuracy: 0.6311
# Features: (0, 2, 3), Kernel: poly, C: 100, Gamma: 0.1, Accuracy: 0.9369
# Features: (0, 2, 3), Kernel: poly, C: 100, Gamma: 1, Accuracy: 0.9466
# Features: (0, 2, 3), Kernel: poly, C: 100, Gamma: 10, Accuracy: 0.9515
# Features: (1, 2, 3), Kernel: linear, C: 0.1, Gamma: 0.01, Accuracy: 0.8301
# Features: (1, 2, 3), Kernel: linear, C: 0.1, Gamma: 0.1, Accuracy: 0.8301
# Features: (1, 2, 3), Kernel: linear, C: 0.1, Gamma: 1, Accuracy: 0.8301
# Features: (1, 2, 3), Kernel: linear, C: 0.1, Gamma: 10, Accuracy: 0.8301
# Features: (1, 2, 3), Kernel: linear, C: 1, Gamma: 0.01, Accuracy: 0.8301
# Features: (1, 2, 3), Kernel: linear, C: 1, Gamma: 0.1, Accuracy: 0.8301
# Features: (1, 2, 3), Kernel: linear, C: 1, Gamma: 1, Accuracy: 0.8301
# Features: (1, 2, 3), Kernel: linear, C: 1, Gamma: 10, Accuracy: 0.8301
# Features: (1, 2, 3), Kernel: linear, C: 10, Gamma: 0.01, Accuracy: 0.8277
# Features: (1, 2, 3), Kernel: linear, C: 10, Gamma: 0.1, Accuracy: 0.8277
# Features: (1, 2, 3), Kernel: linear, C: 10, Gamma: 1, Accuracy: 0.8277
# Features: (1, 2, 3), Kernel: linear, C: 10, Gamma: 10, Accuracy: 0.8277
# Features: (1, 2, 3), Kernel: linear, C: 100, Gamma: 0.01, Accuracy: 0.8277
# Features: (1, 2, 3), Kernel: linear, C: 100, Gamma: 0.1, Accuracy: 0.8277
# Features: (1, 2, 3), Kernel: linear, C: 100, Gamma: 1, Accuracy: 0.8277
# Features: (1, 2, 3), Kernel: linear, C: 100, Gamma: 10, Accuracy: 0.8277
# Features: (1, 2, 3), Kernel: rbf, C: 0.1, Gamma: 0.01, Accuracy: 0.6262
# Features: (1, 2, 3), Kernel: rbf, C: 0.1, Gamma: 0.1, Accuracy: 0.8398
# Features: (1, 2, 3), Kernel: rbf, C: 0.1, Gamma: 1, Accuracy: 0.8908
# Features: (1, 2, 3), Kernel: rbf, C: 0.1, Gamma: 10, Accuracy: 0.9126
# Features: (1, 2, 3), Kernel: rbf, C: 1, Gamma: 0.01, Accuracy: 0.8350
# Features: (1, 2, 3), Kernel: rbf, C: 1, Gamma: 0.1, Accuracy: 0.8374
# Features: (1, 2, 3), Kernel: rbf, C: 1, Gamma: 1, Accuracy: 0.9150
# Features: (1, 2, 3), Kernel: rbf, C: 1, Gamma: 10, Accuracy: 0.9393
# Features: (1, 2, 3), Kernel: rbf, C: 10, Gamma: 0.01, Accuracy: 0.8325
# Features: (1, 2, 3), Kernel: rbf, C: 10, Gamma: 0.1, Accuracy: 0.8714
# Features: (1, 2, 3), Kernel: rbf, C: 10, Gamma: 1, Accuracy: 0.9248
# Features: (1, 2, 3), Kernel: rbf, C: 10, Gamma: 10, Accuracy: 0.9369
# Features: (1, 2, 3), Kernel: rbf, C: 100, Gamma: 0.01, Accuracy: 0.8350
# Features: (1, 2, 3), Kernel: rbf, C: 100, Gamma: 0.1, Accuracy: 0.9102
# Features: (1, 2, 3), Kernel: rbf, C: 100, Gamma: 1, Accuracy: 0.9345
# Features: (1, 2, 3), Kernel: rbf, C: 100, Gamma: 10, Accuracy: 0.9393
# Features: (1, 2, 3), Kernel: poly, C: 0.1, Gamma: 0.01, Accuracy: 0.5558
# Features: (1, 2, 3), Kernel: poly, C: 0.1, Gamma: 0.1, Accuracy: 0.6286
# Features: (1, 2, 3), Kernel: poly, C: 0.1, Gamma: 1, Accuracy: 0.7767
# Features: (1, 2, 3), Kernel: poly, C: 0.1, Gamma: 10, Accuracy: 0.8495
# Features: (1, 2, 3), Kernel: poly, C: 1, Gamma: 0.01, Accuracy: 0.5558
# Features: (1, 2, 3), Kernel: poly, C: 1, Gamma: 0.1, Accuracy: 0.6845
# Features: (1, 2, 3), Kernel: poly, C: 1, Gamma: 1, Accuracy: 0.8204
# Features: (1, 2, 3), Kernel: poly, C: 1, Gamma: 10, Accuracy: 0.8519
# Features: (1, 2, 3), Kernel: poly, C: 10, Gamma: 0.01, Accuracy: 0.5777
# Features: (1, 2, 3), Kernel: poly, C: 10, Gamma: 0.1, Accuracy: 0.6893
# Features: (1, 2, 3), Kernel: poly, C: 10, Gamma: 1, Accuracy: 0.8447
# Features: (1, 2, 3), Kernel: poly, C: 10, Gamma: 10, Accuracy: 0.8544
# Features: (1, 2, 3), Kernel: poly, C: 100, Gamma: 0.01, Accuracy: 0.6286
# Features: (1, 2, 3), Kernel: poly, C: 100, Gamma: 0.1, Accuracy: 0.7767
# Features: (1, 2, 3), Kernel: poly, C: 100, Gamma: 1, Accuracy: 0.8495
# Features: (1, 2, 3), Kernel: poly, C: 100, Gamma: 10, Accuracy: 0.8301
# Features: (0, 1, 2, 3), Kernel: linear, C: 0.1, Gamma: 0.01, Accuracy: 0.9830
# Features: (0, 1, 2, 3), Kernel: linear, C: 0.1, Gamma: 0.1, Accuracy: 0.9830
# Features: (0, 1, 2, 3), Kernel: linear, C: 0.1, Gamma: 1, Accuracy: 0.9830
# Features: (0, 1, 2, 3), Kernel: linear, C: 0.1, Gamma: 10, Accuracy: 0.9830
# Features: (0, 1, 2, 3), Kernel: linear, C: 1, Gamma: 0.01, Accuracy: 0.9854
# Features: (0, 1, 2, 3), Kernel: linear, C: 1, Gamma: 0.1, Accuracy: 0.9854
# Features: (0, 1, 2, 3), Kernel: linear, C: 1, Gamma: 1, Accuracy: 0.9854
# Features: (0, 1, 2, 3), Kernel: linear, C: 1, Gamma: 10, Accuracy: 0.9854
# Features: (0, 1, 2, 3), Kernel: linear, C: 10, Gamma: 0.01, Accuracy: 0.9879
# Features: (0, 1, 2, 3), Kernel: linear, C: 10, Gamma: 0.1, Accuracy: 0.9879
# Features: (0, 1, 2, 3), Kernel: linear, C: 10, Gamma: 1, Accuracy: 0.9879
# Features: (0, 1, 2, 3), Kernel: linear, C: 10, Gamma: 10, Accuracy: 0.9879
# Features: (0, 1, 2, 3), Kernel: linear, C: 100, Gamma: 0.01, Accuracy: 0.9879
# Features: (0, 1, 2, 3), Kernel: linear, C: 100, Gamma: 0.1, Accuracy: 0.9879
# Features: (0, 1, 2, 3), Kernel: linear, C: 100, Gamma: 1, Accuracy: 0.9879
# Features: (0, 1, 2, 3), Kernel: linear, C: 100, Gamma: 10, Accuracy: 0.9879
# Features: (0, 1, 2, 3), Kernel: rbf, C: 0.1, Gamma: 0.01, Accuracy: 0.9175
# Features: (0, 1, 2, 3), Kernel: rbf, C: 0.1, Gamma: 0.1, Accuracy: 0.9854
# Features: (0, 1, 2, 3), Kernel: rbf, C: 0.1, Gamma: 1, Accuracy: 1.0000
# Features: (0, 1, 2, 3), Kernel: rbf, C: 0.1, Gamma: 10, Accuracy: 0.8665
# Features: (0, 1, 2, 3), Kernel: rbf, C: 1, Gamma: 0.01, Accuracy: 0.9806
# Features: (0, 1, 2, 3), Kernel: rbf, C: 1, Gamma: 0.1, Accuracy: 1.0000
# Features: (0, 1, 2, 3), Kernel: rbf, C: 1, Gamma: 1, Accuracy: 1.0000
# Features: (0, 1, 2, 3), Kernel: rbf, C: 1, Gamma: 10, Accuracy: 1.0000
# Features: (0, 1, 2, 3), Kernel: rbf, C: 10, Gamma: 0.01, Accuracy: 0.9927
# Features: (0, 1, 2, 3), Kernel: rbf, C: 10, Gamma: 0.1, Accuracy: 1.0000
# Features: (0, 1, 2, 3), Kernel: rbf, C: 10, Gamma: 1, Accuracy: 1.0000
# Features: (0, 1, 2, 3), Kernel: rbf, C: 10, Gamma: 10, Accuracy: 1.0000
# Features: (0, 1, 2, 3), Kernel: rbf, C: 100, Gamma: 0.01, Accuracy: 1.0000
# Features: (0, 1, 2, 3), Kernel: rbf, C: 100, Gamma: 0.1, Accuracy: 1.0000
# Features: (0, 1, 2, 3), Kernel: rbf, C: 100, Gamma: 1, Accuracy: 1.0000
# Features: (0, 1, 2, 3), Kernel: rbf, C: 100, Gamma: 10, Accuracy: 1.0000
# Features: (0, 1, 2, 3), Kernel: poly, C: 0.1, Gamma: 0.01, Accuracy: 0.5558
# Features: (0, 1, 2, 3), Kernel: poly, C: 0.1, Gamma: 0.1, Accuracy: 0.6820
# Features: (0, 1, 2, 3), Kernel: poly, C: 0.1, Gamma: 1, Accuracy: 0.9903
# Features: (0, 1, 2, 3), Kernel: poly, C: 0.1, Gamma: 10, Accuracy: 1.0000
# Features: (0, 1, 2, 3), Kernel: poly, C: 1, Gamma: 0.01, Accuracy: 0.5558
# Features: (0, 1, 2, 3), Kernel: poly, C: 1, Gamma: 0.1, Accuracy: 0.8786
# Features: (0, 1, 2, 3), Kernel: poly, C: 1, Gamma: 1, Accuracy: 1.0000
# Features: (0, 1, 2, 3), Kernel: poly, C: 1, Gamma: 10, Accuracy: 1.0000
# Features: (0, 1, 2, 3), Kernel: poly, C: 10, Gamma: 0.01, Accuracy: 0.5801
# Features: (0, 1, 2, 3), Kernel: poly, C: 10, Gamma: 0.1, Accuracy: 0.9854
# Features: (0, 1, 2, 3), Kernel: poly, C: 10, Gamma: 1, Accuracy: 1.0000
# Features: (0, 1, 2, 3), Kernel: poly, C: 10, Gamma: 10, Accuracy: 1.0000
# Features: (0, 1, 2, 3), Kernel: poly, C: 100, Gamma: 0.01, Accuracy: 0.6820
# Features: (0, 1, 2, 3), Kernel: poly, C: 100, Gamma: 0.1, Accuracy: 0.9903
# Features: (0, 1, 2, 3), Kernel: poly, C: 100, Gamma: 1, Accuracy: 1.0000
# Features: (0, 1, 2, 3), Kernel: poly, C: 100, Gamma: 10, Accuracy: 1.0000

# %%
print("\nBest Configuration:")
print(f"Features: {best_config[0]}, Kernel: {best_config[1]}, C: {best_config[2]}, Gamma: {best_config[3]}")
print(f"Best Accuracy: {best_accuracy:.4f}")
# Out:
# Best Configuration:
# Features: (0, 1, 2), Kernel: rbf, C: 1, Gamma: 1
# Best Accuracy: 1.0000
